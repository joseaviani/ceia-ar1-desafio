# %%
# %pip install "gymnasium[box2d]" stable-baselines3[extra] torch opencv-python pyyaml
# Out:
# Requirement already satisfied: torch in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (2.11.0)
# Requirement already satisfied: opencv-python in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: pyyaml in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (6.0.3)
# Requirement already satisfied: gymnasium[box2d] in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (1.2.3)
# Requirement already satisfied: stable-baselines3[extra] in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (2.8.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (2.4.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: pandas in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: matplotlib in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (3.10.8)
# Requirement already satisfied: pygame-ce in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (2.5.7)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (2.20.0)
# Requirement already satisfied: psutil in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (7.2.2)
# Requirement already satisfied: tqdm in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (4.67.3)
# Requirement already satisfied: rich in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (15.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from stable-baselines3[extra]) (11.3.0)
# Requirement already satisfied: filelock in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: setuptools<82 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.10.2)
# Requirement already satisfied: packaging in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (26.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (7.34.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tzdata in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from pandas->stable-baselines3[extra]) (2026.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from rich->stable-baselines3[extra]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: colorama in c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import annotations

import argparse
import json
import os
import platform
import random
from dataclasses import asdict, dataclass
from datetime import datetime
from pathlib import Path
from typing import Any

import cv2
import gymnasium as gym
import numpy as np
import torch
import yaml
from gymnasium import spaces
from gymnasium.wrappers import TransformObservation
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv, VecFrameStack, VecMonitor, VecTransposeImage


# -----------------------------
# Config
# -----------------------------

@dataclass
class TrainConfig:
    env_id: str = "CarRacing-v3"
    continuous: bool = True
    seed: int = 0

    n_envs: int = 8
    n_eval_envs: int = 1
    use_subproc: bool = True

    total_timesteps: int = 200_000

    learning_rate: float = 1e-4
    n_steps: int = 1024
    batch_size: int = 128
    n_epochs: int = 10
    gamma: float = 0.99
    gae_lambda: float = 0.95
    clip_range: float = 0.2
    ent_coef: float = 0.0
    vf_coef: float = 0.5
    max_grad_norm: float = 0.5
    use_sde: bool = False
    sde_sample_freq: int = 4
    device: str = "auto"

    ortho_init: bool = False
    log_std_init: float = -2.0
    pi_hidden_size: int = 256
    vf_hidden_size: int = 256

    grayscale: bool = True
    n_stack: int = 4
    normalize_images_manually: bool = False

    eval_freq_steps: int = 25_000
    n_eval_episodes: int = 5
    checkpoint_freq_steps: int = 50_000
    log_root: str = "experiments/carracing_ppo"
    run_name: str | None = None

    record_video: bool = False
    video_length: int = 1_000


# -----------------------------
# Utility functions
# -----------------------------

def set_global_seeds(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def timestamp() -> str:
    return datetime.now().strftime("%Y%m%d_%H%M%S")


def make_run_dirs(cfg: TrainConfig) -> dict[str, Path]:
    run_name = cfg.run_name or f"run_{timestamp()}_seed{cfg.seed}"
    base = Path(cfg.log_root) / run_name
    paths = {
        "base": base,
        "tb": base / "tb",
        "checkpoints": base / "checkpoints",
        "best_model": base / "best_model",
        "eval": base / "eval",
        "videos": base / "videos",
    }
    for path in paths.values():
        path.mkdir(parents=True, exist_ok=True)
    return paths


# -----------------------------
# Observation wrappers
# -----------------------------

class GrayscaleObservation(gym.ObservationWrapper):

    def __init__(self, env: gym.Env):
        super().__init__(env)
        assert isinstance(env.observation_space, spaces.Box)
        obs_space = env.observation_space
        assert len(obs_space.shape) == 3 and obs_space.shape[-1] == 3, (
            f"Expected channel-last RGB image, got shape={obs_space.shape}"
        )
        h, w, _ = obs_space.shape
        self.observation_space = spaces.Box(
            low=0,
            high=255,
            shape=(h, w, 1),
            dtype=np.uint8,
        )

    def observation(self, obs: np.ndarray) -> np.ndarray:
        gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        return gray[..., None].astype(np.uint8)


class Float32NormalizeObservation(gym.ObservationWrapper):

    def __init__(self, env: gym.Env):
        super().__init__(env)
        assert isinstance(env.observation_space, spaces.Box)
        old = env.observation_space
        self.observation_space = spaces.Box(
            low=0.0,
            high=1.0,
            shape=old.shape,
            dtype=np.float32,
        )

    def observation(self, obs: np.ndarray) -> np.ndarray:
        return (obs.astype(np.float32) / 255.0).astype(np.float32)


# -----------------------------
# Env factory
# -----------------------------

def build_single_env(cfg: TrainConfig, rank: int, run_dir: Path, training: bool) -> gym.Env:
    env = gym.make(
        cfg.env_id,
        continuous=cfg.continuous,
        render_mode="rgb_array" if cfg.record_video and not training else None,
    )

    env.action_space.seed(cfg.seed + rank)
    env.reset(seed=cfg.seed + rank)

    if cfg.grayscale:
        env = GrayscaleObservation(env)

    monitor_file = run_dir / f"monitor_{'train' if training else 'eval'}_{rank}.csv"
    env = Monitor(env, filename=str(monitor_file))
    return env


def make_env_fn(cfg: TrainConfig, rank: int, run_dir: Path, training: bool):
    def _init() -> gym.Env:
        return build_single_env(cfg, rank, run_dir, training)
    return _init


# -----------------------------
# Vec env builders
# -----------------------------

def make_train_vec_env(cfg: TrainConfig, paths: dict[str, Path]):
    env_fns = [make_env_fn(cfg, i, paths["base"], training=True) for i in range(cfg.n_envs)]
    if cfg.use_subproc and cfg.n_envs > 1:
        vec_env = SubprocVecEnv(env_fns, start_method="spawn")
    else:
        vec_env = DummyVecEnv(env_fns)

    vec_env = VecMonitor(vec_env, filename=str(paths["base"] / "vec_monitor_train.csv"))
    vec_env = VecFrameStack(vec_env, n_stack=cfg.n_stack)
    vec_env = VecTransposeImage(vec_env)
    return vec_env


def make_eval_vec_env(cfg: TrainConfig, paths: dict[str, Path]):
    env_fns = [make_env_fn(cfg, 10_000 + i, paths["base"], training=False) for i in range(cfg.n_eval_envs)]
    vec_env = DummyVecEnv(env_fns)
    vec_env = VecMonitor(vec_env, filename=str(paths["base"] / "vec_monitor_eval.csv"))
    vec_env = VecFrameStack(vec_env, n_stack=cfg.n_stack)
    vec_env = VecTransposeImage(vec_env)
    return vec_env


# -----------------------------
# Model builder
# -----------------------------

def build_model(cfg: TrainConfig, train_env, paths: dict[str, Path]) -> PPO:
    policy_kwargs: dict[str, Any] = {
        "ortho_init": cfg.ortho_init,
        "log_std_init": cfg.log_std_init,
        "net_arch": {"pi": [cfg.pi_hidden_size], "vf": [cfg.vf_hidden_size]},
    }

    model = PPO(
        policy="CnnPolicy",
        env=train_env,
        learning_rate=cfg.learning_rate,
        n_steps=cfg.n_steps,
        batch_size=cfg.batch_size,
        n_epochs=cfg.n_epochs,
        gamma=cfg.gamma,
        gae_lambda=cfg.gae_lambda,
        clip_range=cfg.clip_range,
        ent_coef=cfg.ent_coef,
        vf_coef=cfg.vf_coef,
        max_grad_norm=cfg.max_grad_norm,
        use_sde=cfg.use_sde,
        sde_sample_freq=cfg.sde_sample_freq,
        policy_kwargs=policy_kwargs,
        tensorboard_log=str(paths["tb"]),
        verbose=1,
        seed=cfg.seed,
        device=cfg.device,
    )
    return model


# -----------------------------
# Callbacks
# -----------------------------

def build_callbacks(cfg: TrainConfig, eval_env, paths: dict[str, Path]) -> CallbackList:
    eval_freq = max(cfg.eval_freq_steps // cfg.n_envs, 1)
    checkpoint_freq = max(cfg.checkpoint_freq_steps // cfg.n_envs, 1)

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=str(paths["best_model"]),
        log_path=str(paths["eval"]),
        eval_freq=eval_freq,
        n_eval_episodes=cfg.n_eval_episodes,
        deterministic=True,
        render=False,
        verbose=1,
    )

    checkpoint_callback = CheckpointCallback(
        save_freq=checkpoint_freq,
        save_path=str(paths["checkpoints"]),
        name_prefix="ppo_carracing",
        save_replay_buffer=False,
        save_vecnormalize=False,
        verbose=1,
    )

    return CallbackList([checkpoint_callback, eval_callback])


# -----------------------------
# Config export
# -----------------------------


def to_yaml_safe(obj):
    if isinstance(obj, dict):
        return {str(k): to_yaml_safe(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return [to_yaml_safe(x) for x in obj]
    if isinstance(obj, (str, int, float, bool)) or obj is None:
        return obj
    if hasattr(obj, "item"):
        try:
            return obj.item()
        except Exception:
            return str(obj)
    return str(obj)

def export_config(cfg: TrainConfig, paths: dict[str, Path]) -> None:
    payload = asdict(cfg)
    payload["timestamp"] = str(datetime.now().isoformat())
    payload["python_version"] = str(platform.python_version())
    payload["platform"] = str(platform.platform())
    payload["torch_version"] = str(torch.__version__)
    payload["cuda_available"] = bool(torch.cuda.is_available())

    try:
        import stable_baselines3
        payload["stable_baselines3_version"] = str(stable_baselines3.__version__)
    except Exception:
        payload["stable_baselines3_version"] = "unknown"

    try:
        import gymnasium
        payload["gymnasium_version"] = str(gymnasium.__version__)
    except Exception:
        payload["gymnasium_version"] = "unknown"

    payload = to_yaml_safe(payload)

    with open(paths["base"] / "config.yaml", "w", encoding="utf-8") as f:
        yaml.safe_dump(payload, f, sort_keys=False, allow_unicode=True)

    with open(paths["base"] / "config.json", "w", encoding="utf-8") as f:
        json.dump(payload, f, indent=2, ensure_ascii=False)




def get_config() -> TrainConfig:

    seed = 0 # default 0
    total_timesteps = 200000 # default 200000
    n_envs = 8 # default 8
    run_name = None # default None
    log_root = "experiments/carracing_ppo" # default "experiments/carracing_ppo"
    device = "auto" # default "auto"
    dummy_vec = True # default False

    return TrainConfig(
        seed=seed,
        total_timesteps=total_timesteps,
        n_envs=n_envs,
        run_name=run_name,
        log_root=log_root,
        device=device,
        use_subproc=not dummy_vec
    )


# -----------------------------
# Main
# -----------------------------

def main() -> None:
    cfg = get_config()
    set_global_seeds(cfg.seed)
    paths = make_run_dirs(cfg)
    export_config(cfg, paths)

    print("=" * 80)
    print("CarRacing-v3 PPO baseline")
    print(f"Run dir:          {paths['base']}")
    print(f"Seed:             {cfg.seed}")
    print(f"Total timesteps:  {cfg.total_timesteps}")
    print(f"Parallel envs:    {cfg.n_envs}")
    print(f"Eval every:       {cfg.eval_freq_steps} env steps")
    print(f"Checkpoint every: {cfg.checkpoint_freq_steps} env steps")
    print("=" * 80)

    train_env = make_train_vec_env(cfg, paths)
    eval_env = make_eval_vec_env(cfg, paths)

    model = build_model(cfg, train_env, paths)
    callbacks = build_callbacks(cfg, eval_env, paths)

    try:
        model.learn(
            total_timesteps=cfg.total_timesteps,
            callback=callbacks,
            progress_bar=True,
            tb_log_name="ppo_carracing",
            reset_num_timesteps=True,
        )

        final_model_path = paths["base"] / "final_model.zip"
        model.save(str(final_model_path))
        print(f"Saved final model to: {final_model_path}")
        print(f"Best model path:      {paths['best_model']}")
        print(f"TensorBoard log dir:  {paths['tb']}")

    finally:
        train_env.close()
        eval_env.close()

# %%
main()
# Out:
# ================================================================================
# CarRacing-v3 PPO baseline
# Run dir:          experiments\carracing_ppo\run_20260422_173354_seed0
# Seed:             0
# Total timesteps:  200000
# Parallel envs:    8
# Eval every:       25000 env steps
# Checkpoint every: 50000 env steps
# ================================================================================
# c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages\stable_baselines3\common\vec_env\vec_monitor.py:43: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# Using cpu device
# Logging to experiments\carracing_ppo\run_20260422_173354_seed0\tb\ppo_carracing_1
# c:\Users\Jose\CEIA\Materias\Aprendizaje por Refuerzo I\Desafio\Codigo\.venv\Lib\site-packages\rich\live.py:260:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -45.8    |
# | time/              |          |
# |    fps             | 99       |
# |    iterations      | 1        |
# |    time_elapsed    | 82       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009774753 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.75        |
# |    explained_variance   | -5.96e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.387       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00209     |
# |    std                  | 0.135       |
# |    value_loss           | 0.886       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46         |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 3           |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011472691 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.76        |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.288       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000121   |
# |    std                  | 0.134       |
# |    value_loss           | 0.613       |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=-58.24 +/- 0.59
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -58.2        |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0072324914 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.77         |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.316        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.134        |
# |    value_loss           | 0.708        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -47.7    |
# | time/              |          |
# |    fps             | 60       |
# |    iterations      | 4        |
# |    time_elapsed    | 545      |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.8       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 5           |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007746109 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.79        |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.192       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00167    |
# |    std                  | 0.133       |
# |    value_loss           | 0.418       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.9       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 6           |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009693393 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.8         |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.128       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 4.95e-05    |
# |    std                  | 0.133       |
# |    value_loss           | 0.419       |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=-53.78 +/- 2.67
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -53.8       |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.009073846 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.82        |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.223       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000118   |
# |    std                  | 0.132       |
# |    value_loss           | 0.379       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -49.1    |
# | time/              |          |
# |    fps             | 57       |
# |    iterations      | 7        |
# |    time_elapsed    | 999      |
# |    total_timesteps | 57344    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -48.9        |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 8            |
# |    time_elapsed         | 1137         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0077925185 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.83         |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.223        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000668    |
# |    std                  | 0.131        |
# |    value_loss           | 0.396        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 9           |
# |    time_elapsed         | 1284        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010927943 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.84        |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.163       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000444   |
# |    std                  | 0.131       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# Eval num_timesteps=75000, episode_reward=-56.37 +/- 0.76
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -56.4       |
# | time/                   |             |
# |    total_timesteps      | 75000       |
# | train/                  |             |
# |    approx_kl            | 0.010180119 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.85        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.163       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 2.73e-06    |
# |    std                  | 0.131       |
# |    value_loss           | 0.407       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -48.2    |
# | time/              |          |
# |    fps             | 55       |
# |    iterations      | 10       |
# |    time_elapsed    | 1475     |
# |    total_timesteps | 81920    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.4       |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 11          |
# |    time_elapsed         | 1610        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014517022 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.86        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.136       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00335    |
# |    std                  | 0.13        |
# |    value_loss           | 0.313       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.1       |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 12          |
# |    time_elapsed         | 1747        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012903411 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.88        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.122       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00404    |
# |    std                  | 0.129       |
# |    value_loss           | 0.382       |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=-34.40 +/- 4.40
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -34.4       |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.009851315 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.89        |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0903      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00433    |
# |    std                  | 0.129       |
# |    value_loss           | 0.416       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -44.3    |
# | time/              |          |
# |    fps             | 53       |
# |    iterations      | 13       |
# |    time_elapsed    | 1995     |
# |    total_timesteps | 106496   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 14          |
# |    time_elapsed         | 2164        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009897204 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.91        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.203       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00338    |
# |    std                  | 0.128       |
# |    value_loss           | 0.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -38.6       |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 15          |
# |    time_elapsed         | 2345        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.011198532 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.189       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0043     |
# |    std                  | 0.127       |
# |    value_loss           | 0.506       |
# -----------------------------------------
# Eval num_timesteps=125000, episode_reward=-22.22 +/- 9.46
# Episode length: 908.60 +/- 182.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 909         |
# |    mean_reward          | -22.2       |
# | time/                   |             |
# |    total_timesteps      | 125000      |
# | train/                  |             |
# |    approx_kl            | 0.011933835 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.95        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.211       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 0.126       |
# |    value_loss           | 0.444       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -35.7    |
# | time/              |          |
# |    fps             | 50       |
# |    iterations      | 16       |
# |    time_elapsed    | 2588     |
# |    total_timesteps | 131072   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -28.1       |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 17          |
# |    time_elapsed         | 2753        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.009679783 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.115       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00324    |
# |    std                  | 0.126       |
# |    value_loss           | 0.472       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -26         |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 18          |
# |    time_elapsed         | 2922        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.011756644 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.98        |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.16        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00448    |
# |    std                  | 0.125       |
# |    value_loss           | 0.471       |
# -----------------------------------------
# Eval num_timesteps=150000, episode_reward=1.33 +/- 105.01
# Episode length: 694.00 +/- 166.84
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 694         |
# |    mean_reward          | 1.33        |
# | time/                   |             |
# |    total_timesteps      | 150000      |
# | train/                  |             |
# |    approx_kl            | 0.009728184 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.99        |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.123       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00324    |
# |    std                  | 0.124       |
# |    value_loss           | 0.305       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -20.9    |
# | time/              |          |
# |    fps             | 49       |
# |    iterations      | 19       |
# |    time_elapsed    | 3143     |
# |    total_timesteps | 155648   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -16.9      |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 20         |
# |    time_elapsed         | 3310       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.11551374 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.01       |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.167      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0132    |
# |    std                  | 0.124      |
# |    value_loss           | 7.83       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -11.9      |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 21         |
# |    time_elapsed         | 3478       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.01097229 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.02       |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.205      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.000292  |
# |    std                  | 0.124      |
# |    value_loss           | 0.42       |
# ----------------------------------------
# Eval num_timesteps=175000, episode_reward=-6.86 +/- 61.54
# Episode length: 578.00 +/- 119.34
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 578         |
# |    mean_reward          | -6.86       |
# | time/                   |             |
# |    total_timesteps      | 175000      |
# | train/                  |             |
# |    approx_kl            | 0.007814657 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.03        |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0745      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00473    |
# |    std                  | 0.123       |
# |    value_loss           | 0.394       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 997      |
# |    ep_rew_mean     | -7.37    |
# | time/              |          |
# |    fps             | 48       |
# |    iterations      | 22       |
# |    time_elapsed    | 3689     |
# |    total_timesteps | 180224   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | 5.96       |
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 23         |
# |    time_elapsed         | 3854       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.08503555 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.05       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.404      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00392   |
# |    std                  | 0.122      |
# |    value_loss           | 3.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | 21.6        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 24          |
# |    time_elapsed         | 4018        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.009583231 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.06        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.32        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00731    |
# |    std                  | 0.122       |
# |    value_loss           | 0.939       |
# -----------------------------------------
# Eval num_timesteps=200000, episode_reward=96.78 +/- 145.51
# Episode length: 719.80 +/- 260.40
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 720         |
# |    mean_reward          | 96.8        |
# | time/                   |             |
# |    total_timesteps      | 200000      |
# | train/                  |             |
# |    approx_kl            | 0.014132468 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.08        |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.309       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00955    |
# |    std                  | 0.121       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 997      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    fps             | 48       |
# |    iterations      | 25       |
# |    time_elapsed    | 4240     |
# |    total_timesteps | 204800   |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved final model to: experiments\carracing_ppo\run_20260422_173354_seed0\final_model.zip
# Best model path:      experiments\carracing_ppo\run_20260422_173354_seed0\best_model
# TensorBoard log dir:  experiments\carracing_ppo\run_20260422_173354_seed0\tb
